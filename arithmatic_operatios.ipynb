# %% [markdown]
# <a href="https://colab.research.google.com/github/anil3214/python-Basics/blob/main/arithmatic_operatios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1 = 5
num2 = 10

# Calculate the sum
sum_of_numbers = num1 + num2

# Print the result
print(f"The sum of {num1} and {num2} is: {sum_of_numbers}")
