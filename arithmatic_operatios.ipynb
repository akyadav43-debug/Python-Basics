# %% [markdown]
# **Basic operations: Addition,Subtraction,Multiplication,Division,Floor Division,Modulus**

# %%
a=12
b=10
#addition
a+b
# Out:
# 22

# %%
#subraction
a-b
# Out:
# 2

# %%
#multiplication
a*b
# Out:
# 120

# %%
#division
a/b
# Out:
# 1.2

# %%
a//b #floor division
# Out:
# 1

# %%
#Modulus/Remainder
a%b
# Out:
# 2

# %%
#Bodmas
print((4*5)-9+6/7)
# Out:
# 11.857142857142858
