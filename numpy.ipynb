# %% [markdown]
# Numpy library

# %%
import numpy as np

# %%
a= np.array([1,2,3,4,5])

# %%
print(a)
a
# Out:
# [1 2 3 4 5]
# array([1, 2, 3, 4, 5])

# %%
type(a)
# Out:
# numpy.ndarray

# %%
a=np.array([1, 2, 3], dtype=float)
a
# Out:
# array([1., 2., 3.])

# %%
a=np.array([1, 2, 3], dtype=str)
a
# Out:
# array(['1', '2', '3'], dtype='<U1')

# %%
len(a)
# Out:
# 3
