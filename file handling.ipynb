# %%
print("hello")
# Out:
# hello

# %%
file=open("hello world.txt", "r")
for line in file:
   print(line)
# Out:
# hello world
#
# my name is anil kumar yadav
#
# this is text file

# %%
file=open("hello world.txt", "r")
print(file.read())
# Out:
# hello world
# my name is anil kumar yadav
# this is text file

# %%
file=open("hello world.txt", "r")
print(file.read(5))
# Out:
# hello

# %%
file=open("hello world.txt", "r")
print(file.readline(50))
# Out:
# hello world

# %% [markdown]
# Writing a file

# %%
file=open("hello world.txt", "w")
file.write("hello world  ")
file.write("this is my first file handling proogram")
file.close()
file=open("hello world.txt", "r")
print(file.read())
# Out:
# hello world  this is my first file handling proogram

# %% [markdown]
# Append operation

# %%
with open("hello world.txt", "a") as file:   
    file.write("this is append operation")

# %%
file=open("hello world.txt", "r")
print(file.read())
# Out:
# hello world  this is my first file handling proogramthis is append operationthis is append operationthis is append operationthis is append operation
# this is append operation
# this is append operationthis is append operationthis is append operation

# %%
#####Noperation

# %%
with open("hello world.txt", "a+") as file:
    file.write("\n")
    file.write("this is append operation")
    file.seek(0)
    print(file.read())
# Out:
# hello world  this is my first file handling proogramthis is append operationthis is append operationthis is append operationthis is append operation
# this is append operation
# this is append operation

# %%
###REading file using pandas

# %%
import pandas as pd
