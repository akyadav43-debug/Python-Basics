# %% [markdown]
# Variables and Keywords

# %%
a='hello'
print(a)
type(a)
# Out:
# hello
# str

# %%
my_age=26
print(my_age)
# Out:
# 26

# %%
type(my_age)
# Out:
# int

# %%
a=True
type(a)
# Out:
# bool

# %%
a='True'
b='10.5'
print(type(a))
type(b)
# Out:
# <class 'str'>
# str

# %%
def sum_function(a,b):
  c=a+b
  return c

# %%
sum_function(5,8)
# Out:
# 13
