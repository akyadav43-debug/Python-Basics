# %% [markdown]
# <a href="https://colab.research.google.com/github/anil3214/python-Datatypes/blob/main/Datatypes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello')
# Out:
# hello
