# %%
print('hello')
# Out:
# hello

# %%
name = 'Anil'
print(name)
type(name)
# Out:
# Anil
# str

# %%
name=input('enter ypur name:')
print('hello', name)
# Out:
# enter ypur name:Anil
# hello Anil

# %%
a= True
b= 'True'
print(type(a))
print(type(b))
# Out:
# <class 'bool'>
# <class 'str'>

# %% [markdown]
# Typecasting\

# %%
accuracy: 91.2%

# %%
acc=91.2
print(acc)
print(type(acc))
int(acc)
# Out:
# 91.2
# <class 'float'>
# 91

# %%
var=2
print(type(var))
print(var)
# Out:
# <class 'int'>
# 2

# %%
var1=float(var)
print(var1)
print(type(var1))
# Out:
# 2.0
# <class 'float'>

# %%
var=2.9
var_int=int(var)
print(var_int)
print(var)
print(type(var))
print(type(var_int))
# Out:
# 2
# 2.9
# <class 'float'>
# <class 'int'>

# %%
var=2
var2=str(var)
print(var)
print(var2)
print(type(var))
print(type(var2))
# Out:
# 2
# 2
# <class 'int'>
# <class 'str'>

# %%
var3= "2"
print(var3)
print(type(var3))
var4=int(var3)
print(var4)
print(type(var4))
# Out:
# 2
# <class 'str'>
# 2
# <class 'int'>

# %%
var4= "2.5"
print(var4)
print(type(var4))
var5=float(var4)
print(var5)
print(type(var5))
var6=int(var5)
print(var6)
print(type(var6))
# Out:
# 2.5
# <class 'str'>
# 2.5
# <class 'float'>
# 2
# <class 'int'>

# %%
strng= 'Hello'
print(strng[0])
print(strng[1])
print(strng[2])
print(strng[3])
print(strng[4])
print(strng[-1])
print(strng[-2])
print(strng[-3])
print(strng[-4])
print(strng[-5])
# Out:
# H
# e
# l
# l
# o
# o
# l
# l
# e
# H

# %%
str='Hello'
